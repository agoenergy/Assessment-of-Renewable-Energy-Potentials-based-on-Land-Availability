# %% [markdown]
# # Assessment of Renewable Energy Potentials based on Land Availability

# %% [markdown]
# The analysis of land availability for renewable energy potentials is divided into three stages. In this script, we will focus on the first stage: **Land Evaluation**.
#
# -Goal: find out available lands that can be used for renewable energy development.
#
# -Steps:
#
# 1. Import data
# 2. Data unification
# 3. Calculate the total area and plot the map
# 4. Merge the layers

# %%
# import necessary library
# %matplotlib inline
import matplotlib.pyplot as plt # graph plotting package
import os # operating system interfaces 
import numpy as np # array and data sorting package
import pandas as pd # dataframe sorting package
import geopandas # geospatial data processing package
import shapely.speedups # geospatial data speedup package
import rasterio # geospatial data (raster file) processing package
import pyproj # self-defined coordination reference system
from matplotlib.patches import Patch # for legend editing
from pyproj import CRS # self-defined coordination reference system
from geopandas import datasets, GeoDataFrame, read_file # geospatial data processing package
from geopandas.tools import overlay # for overlay function
from shapely import wkt # provide dumpers and loaders inspired by Python’s pickle module
from shapely.geometry import Point # processing for data in point form
from rasterio.plot import show # plot the raster data
from pyproj import Geod # performs forward and inverse geodetic, or Great Circle, computations

# %%
# spped up the calculation of mapping in shapely library
shapely.speedups.enable()

# %%
name = input('Country name of this assessment:')
# enter the country name to assign the value
# Out:
# Country name of this assessment: Vietnam

# %% [markdown]
# ## 1. Import data

# %% [markdown]
# a. Import the **basemap** which is the **administrative level in Vietnam (VN)**. Here we use **level 2** to proceed.
#
# b. Import the **map layers** that are occupied and not suitable for renewable energy development. Here the layers include:
#
# (a) Landuse Map (residential areas, industrial areas, military areas, etc.) <br>
# (b) Building Map (building outline from a bird's eye view)<br>
# (c) Water Areas Map (Rivers, Lakes, Reservoirs, Docks, Glaciers, etc.) <br>
# (d) Roads Map (road networks, highways, etc)<br>
# (e) Railways Map (Railways, Subways, Trams, Lifts, and Cable Cars) <br>
# (f) Transport Stations Map (railway stations, subway stations, airports, aprons) <br>
# *The descriptions of the categories can be found in [OpenStreetMap](http://download.geofabrik.de/osm-data-in-gis-formats-free.pdf)

# %%
# gdf: geodataframe
adminmap = os.path.abspath('Vietnam/00_data_vector/01_admin_level2/vnm_admbnda_adm2_gov_20201027.shp')
# %time adminmap_gdf = geopandas.read_file(adminmap)
# Out:
# Wall time: 425 ms

# %%
# (a) Landuse (forests, parks, residential, industrial, military, etc.) (polygon)
land = os.path.abspath('Vietnam/00_data_vector/02_occupied_land/gis_osm_landuse_a_free_1.shp')
# %time land_gdf = geopandas.read_file(land)

# (b) Building (polygon)
building = os.path.abspath('Vietnam/00_data_vector/03_buildings/gis_osm_buildings_a_free_1.shp')
# %time building_gdf = geopandas.read_file(building)

# (c) Water Areas Map (Rivers, Lakes, Reservoirs, Docks, Glaciers, etc.)
water = os.path.abspath('Vietnam/00_data_vector/04_water_area/gis_osm_water_a_free_1.shp')
# %time water_gdf = geopandas.read_file(water)

# (d) Roads Map (road networks, highways, etc) (line)
roads = os.path.abspath('Vietnam/00_data_vector/05_roads/gis_osm_roads_free_1.shp')
# %time roads_gdf = geopandas.read_file(roads)

# (e) Railways Map (Line) (Railways, Subways, Trams, Lifts, and Cable Cars)
rails = os.path.abspath('Vietnam/00_data_vector/06_railways/gis_osm_railways_free_1.shp')
# %time rails_gdf = geopandas.read_file(rails)

# (f) Transport Stations Map (railway stations, subway stations, airports, aprons)
transport = os.path.abspath('Vietnam/00_data_vector/07_transport_stations/gis_osm_transport_free_1.shp')
# %time transport_gdf = geopandas.read_file(transport)
# Out:
# Wall time: 1.57 s
# Wall time: 31.4 s
# Wall time: 1.44 s
# Wall time: 1min 38s
# Wall time: 173 ms
# Wall time: 261 ms

# %% [markdown]
# ## 2. Data Unification

# %% [markdown]
# ### a. Sort and re-index the **basemap** (**administrative level in Vietnam (VN)**)

# %%
print(adminmap_gdf.columns)
# Out:
# Index(['Shape_Leng', 'Shape_Area', 'ADM2_EN', 'ADM2_VI', 'ADM2_PCODE',
#        'ADM2_REF', 'ADM2ALT1EN', 'ADM2ALT2EN', 'ADM2ALT1VI', 'ADM2ALT2VI',
#        'ADM1_EN', 'ADM1_VI', 'ADM1_PCODE', 'ADM0_EN', 'ADM0_VI', 'ADM0_PCODE',
#        'date', 'validOn', 'validTo', 'geometry'],
#       dtype='object')

# %%
# drop columns that are not needed for calculations
map_drop_gdf = adminmap_gdf.drop(columns=['Shape_Leng','Shape_Area', 'ADM1_VI', 'ADM2_VI', 'ADM2_PCODE', 'ADM2_REF', 
                                           'ADM2ALT1EN', 'ADM2ALT2EN', 'ADM2ALT1VI','ADM2ALT2VI','ADM1_PCODE','ADM0_EN','ADM0_VI','ADM0_PCODE',
                                           'date','validOn','validTo'])
#rename the titles
# create a dictionary and renew the titles
dict = {'NAME_0': 'country_name',
        'NAME_1': 'ad_lv_1',
        'VARNAME_2': 'ad_lv_2',
        'geometry': 'geometry'}
  
# call rename () method
map_drop_gdf.rename(columns=dict,
          inplace=True)
  
map_drop_gdf.head()
# Out:
#     ADM2_EN         ADM1_EN                                           geometry
# 0    A Luoi  Thua Thien Hue  POLYGON ((107.08980 16.44847, 107.09281 16.446...
# 1   An Bien      Kien Giang  POLYGON ((105.12050 9.85495, 105.12673 9.84550...
# 2  An Duong  Hai Phong city  POLYGON ((106.57189 20.93209, 106.57247 20.931...
# 3    An Khe         Gia Lai  POLYGON ((108.68734 14.12817, 108.68975 14.125...
# 4    An Lao  Hai Phong city  POLYGON ((106.48482 20.86676, 106.48501 20.866...

# %% [markdown]
# ### b. Sort and re-index the other map layers.
# Only three columns shall be kept: **type/fclass, name, geometry**

# %%
# list the titles of each column for selection
titles_array = [land_gdf,building_gdf,water_gdf,roads_gdf,rails_gdf,transport_gdf]

for i in titles_array:
    print(i.columns)
# Out:
# Index(['osm_id', 'code', 'fclass', 'name', 'geometry'], dtype='object')
# Index(['osm_id', 'code', 'fclass', 'name', 'type', 'geometry'], dtype='object')
# Index(['osm_id', 'code', 'fclass', 'name', 'geometry'], dtype='object')
# Index(['osm_id', 'code', 'fclass', 'name', 'ref', 'oneway', 'maxspeed',
#        'layer', 'bridge', 'tunnel', 'geometry'],
#       dtype='object')
# Index(['osm_id', 'code', 'fclass', 'name', 'layer', 'bridge', 'tunnel',
#        'geometry'],
#       dtype='object')
# Index(['osm_id', 'code', 'fclass', 'name', 'geometry'], dtype='object')

# %%
# drop columns that are not needed for calculations
land_drop_gdf = land_gdf.drop(columns=['osm_id','code'])
building_drop_gdf = building_gdf.drop(columns=['osm_id','code', 'type'])
water_drop_gdf =water_gdf.drop(columns=['osm_id','code'])

# remove unnecessary columns
roads_drop_gdf = roads_gdf.drop(columns=['osm_id','code','ref','maxspeed','layer','bridge','tunnel', 'oneway'])
# road data needs to be reduced since it is too detailed
# set up a list that need to remove. And remove the names in column 'fclass' that are included in the list.
# drop columns that are not needed for calculations
drop_roads = ['footway','residential','unclassified','living_street','pedestrian','track_grade1','bridleway','path','steps','unknown']
roads_drop_gdf = roads_drop_gdf[~roads_drop_gdf['fclass'].isin(drop_roads)]

# remove unnecessary columns
rails_drop_gdf = rails_gdf.drop(columns=['osm_id','code','layer','bridge','tunnel'])
# rails data needs to be reduced since it is too detailed
# set up a list that need to remove. And remove the names in column 'fclass' that are included in the list.
# drop columns that are not needed for calculations
drop_rails = ['subway','drag_lift','chair_lift','cable_car','gondola','goods','other_lift']
rails_drop_gdf = rails_drop_gdf[~rails_drop_gdf['fclass'].isin(drop_rails)]

# remove unnecessary columns
trans_drop_gdf = transport_gdf.drop(columns=['osm_id','code'])
# transport data needs to be reduced since it is too detailed
# set up a list that need to remove. And remove the names in column 'fclass' that are included in the list.
# drop columns that are not needed for calculations
drop_trans = ['tram_stop','bus_stop','bus_station','taxi_rank','helipad','ferry_terminal','aerialway_station']
trans_drop_gdf = trans_drop_gdf[~trans_drop_gdf['fclass'].isin(drop_trans)]

layers = [land_drop_gdf,building_drop_gdf,water_drop_gdf,roads_drop_gdf,rails_drop_gdf,trans_drop_gdf]

for i in layers:
    print(i.columns)
# Out:
# Index(['fclass', 'name', 'geometry'], dtype='object')
# Index(['fclass', 'name', 'geometry'], dtype='object')
# Index(['fclass', 'name', 'geometry'], dtype='object')
# Index(['fclass', 'name', 'geometry'], dtype='object')
# Index(['fclass', 'name', 'geometry'], dtype='object')
# Index(['fclass', 'name', 'geometry'], dtype='object')

# %% [markdown]
# ### c. Scale up the **buffer** of each vector

# %%
# Polygon file (land use, building, water)
# String file (roads, railways, transportation)
# functions of geopandas package
# increase the buffer to make every layer become polygons (longitude crs. unit in 0.01 degree of longitude (1.11 km))
for layer in layers:
        layer['geometry'] = layer.geometry.buffer(0.01, cap_style = 3, join_style = 1)
# Out:
# <ipython-input-11-04b80b3724a4>:6: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   layer['geometry'] = layer.geometry.buffer(0.01, cap_style = 3, join_style = 1)

# %% [markdown]
# ## 3. Calculate the total area and plot the map

# %% [markdown]
# [EPSG:4326/WGS 84](https://epsg.io/4326) - World Geodetic System 1984, used in GPS (common longtitude/latitude system) <br>
# [EPSG:3405/VN-2000 / UTM zone 48N](https://epsg.io/3405) - Accurate projection and caluclation of areas (units in meters) <br>
# *UTM: Universal Transverse Mercator coordinate system
#
# ### a. Calculate the total area of Vietnam via **basemap** (**administrative level in Vietnam (VN)**)

# %%
# check the CRS of all layers
layers_crs = [map_drop_gdf, land_drop_gdf,building_drop_gdf,water_drop_gdf,roads_drop_gdf,rails_drop_gdf,trans_drop_gdf]

for i in layers_crs:
    print(i.crs)
# Out:
# epsg:4326
# epsg:4326
# epsg:4326
# epsg:4326
# epsg:4326
# epsg:4326
# epsg:4326

# %%
# crs for meter
# from https://epsg.io/
crs_m = CRS.from_proj4("+proj=utm +zone=48 +ellps=WGS84 +towgs84=-192.873,-39.382,-111.202,-0.00205,-0.0005,0.00335,0.0188 +units=m +no_defs ")
crs_m
# Out:
# <Bound CRS: +proj=utm +zone=48 +ellps=WGS84 +towgs84=-192.873, ...>
# Name: unknown
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - undefined
# Coordinate Operation:
# - name: Transformation from unknown to WGS84
# - method: Position Vector transformation (geog2D domain)
# Datum: Unknown based on WGS84 ellipsoid
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich
# Source CRS: unknown

# %%
# Original CRS: EPSG:4326 (Unit: longtitude, latitiude)
# Reprojection to crs
map_m_gdf = map_drop_gdf.to_crs(crs_m)
# Areas in square kilometers
map_km_df = map_m_gdf.area/ 10**6

print('Total area of', name, ':', map_km_df.sum(axis = 0, skipna = True),'km^2')
# Out:
# Total area of Vietnam : 334820.73259775393 km^2

# %% [markdown]
# Compared to the [official value of total area (310,070 km^2 in 2018)](https://data.worldbank.org/indicator/AG.LND.TOTL.K2?locations=VN), there are deviations because the data is calculated based on different CRSs, the projections of the map will cause the differences.

# %% [markdown]
# ### b. Plot the maps and save the graphs
# *The graphs below are just for visualization and they are not related to the further programming process. Hence the code lines for storing the graphs are kep in notes. You can also re-validate them if you want to run the output graph files.

# %%
# Plot and save the tiff files
# basemap to the plot (grey)
# ax.set_xlim(101, 110)
# ax.set_ylim(8, 24)
map_drop_gdf.plot(color='#95A5A6')
# plt.savefig(r'01_output_stage1/00_admin_level_2.tiff', dpi=500)   

# roads layer to the plot (black)
roads_drop_gdf.plot(color='#17202A')
# plt.savefig(r'Vietnam/01_output_stage1/00_vn_roads.tiff', dpi=500)

# rails layer to the plot (brown)
rails_drop_gdf.plot(color='#935116')
# plt.savefig(r'Vietnam/01_output_stage1/00_vn_rails.tiff', dpi=500)

# water layer to the plot (blue)
water_drop_gdf.plot(color='#2874A6')
# plt.savefig(r'Vietnam/01_output_stage1/00_vn_water.tiff', dpi=500)

# trasnport layer to the plot (purple)
trans_drop_gdf.plot(color='#5B2C6F')
# plt.savefig(r'Vietnam/01_output_stage1/00_vn_transport.tiff', dpi=500)

# land use layer to the plot (green)
land_drop_gdf.plot(color='g')
# plt.savefig(r'Vietnam/01_output_stage1/00_vn_landuse.tiff', dpi=500)

# add the building layer to the plot (red)
building_drop_gdf.plot(color='#E74C3C')
# plt.savefig(r'Vietnam/01_output_stage1/00_vn_building.tiff', dpi=500)
# Out:
# <AxesSubplot:>

# %%
# Land Use Map Analysis Picture
# Plot the data with a modified spatial extent
fig, ax = plt.subplots(figsize=(10, 20))

# Use VN_landuse boundary to define all sizes of the maps
ax.set_xlim(101, 110)
ax.set_ylim(8, 24)

# add basemap to the plot (grey)
map_drop_gdf.plot(ax=ax, categorical=True, legend=True, color='#95A5A6')
# add the roads layer to the plot (black)
roads_drop_gdf.plot(ax=ax, markersize=10, alpha=0.7, categorical=True, legend=True, color='#17202A')
# add the rails layer to the plot (brown)
rails_drop_gdf.plot(ax=ax, markersize=10, alpha=0.7, categorical=True, legend=True, color='#935116')
# add the water layer to the plot (blue)
water_drop_gdf.plot(ax=ax, markersize=10, alpha=0.7, categorical=True, legend=True, color='#2874A6')
# add the trasnport layer to the plot (purple)
trans_drop_gdf.plot(ax=ax, markersize=10, alpha=0.7, categorical=True, legend=True, color='#5B2C6F')
# add the land use layer to the plot (green)
land_drop_gdf.plot(ax=ax, markersize=10, alpha=0.7, categorical=True, legend=True, color='g')
# add the building layer to the plot (red)
building_drop_gdf.plot(ax=ax, markersize=10, alpha=1.0, categorical=True, legend=True, color='#E74C3C')

# Define Legend
legend_elements = [Patch(facecolor='#95A5A6', label='Administrative level 2'),
                   Patch(facecolor='g', label='Land occupied'),
                   # Patch(facecolor='#58D68D', label='VN protected areas & heritages'),
                   Patch(facecolor='#E74C3C', label='Buildings'),
                   Patch(facecolor='#2874A6', label='Water areas'),
                   Patch(facecolor='#17202A', label='Roads & highways'),
                   Patch(facecolor='#935116', label='Railways'),
                   Patch(facecolor='#5B2C6F', label='Transport stations')]

ax.legend(handles=legend_elements, loc='lower left')

# Set title
ax.set_title("Vietnam Land Use\n(Total Land Area: {0:.{1}f}km\u00b2)".format(map_km_df.sum(axis = 0, skipna = True), 2), fontsize=20)
ax.set_axis_off()

plt.savefig(r'Vietnam/01_output_stage1/01_vn_land_use_analysis.tiff', dpi=500)
plt.show()

# %% [markdown]
# ### c. Save the CSV files

# %%
# Save csv file
# remove column 'geometry' and add column 'area'
map_save_gdf = map_m_gdf.drop(columns=['geometry'])
map_save_gdf['area_km2'] = map_km_df

map_save_gdf.to_csv(r'Vietnam/01_output_stage1/01_vn_admin_level2.csv', index = True)

# %% [markdown]
# ## 4. Merge the layers

# %% [markdown]
# ### a. Merging process
# *It may take some time: approx. 15min

# %%
# Overlay: basemap minu all occupied land layers  
# %time merge1_gdf = geopandas.overlay(map_drop_gdf, rails_drop_gdf, how = 'difference')
# %time merge2_gdf = geopandas.overlay(merge1_gdf, trans_drop_gdf, how = 'difference')
# %time merge3_gdf = geopandas.overlay(merge2_gdf, water_drop_gdf, how = 'difference')
# Out:
# Wall time: 3.63 s
# Wall time: 903 ms
# Wall time: 30.9 s

# %%
# %time merge4_gdf = geopandas.overlay(merge3_gdf, land_drop_gdf, how = 'difference')
# %time merge5_gdf = geopandas.overlay(merge4_gdf, building_drop_gdf, how = 'difference')
# %time merge6_gdf = geopandas.overlay(merge5_gdf, roads_drop_gdf, how = 'difference')
# Out:
# Wall time: 23 s
# Wall time: 1min 46s
# Wall time: 9min 27s

# %%
# after completing merging all layers
merge6_gdf
# Out:
#        ADM2_EN         ADM1_EN  \
# 0       A Luoi  Thua Thien Hue
# 1      An Bien      Kien Giang
# 3       An Khe         Gia Lai
# 5       An Lao       Binh Dinh
# 6      An Minh      Kien Giang
# ..         ...             ...
# 703  Yen Phong        Bac Ninh
# 704    Yen Son     Tuyen Quang
# 705  Yen Thanh         Nghe An
# 706    Yen The       Bac Giang
# 707   Yen Thuy        Hoa Binh
#
#                                               geometry
# 0    MULTIPOLYGON (((107.30808 16.27940, 107.30792 ...
# 1    MULTIPOLYGON (((105.13246 9.78823, 105.13289 9...
# 3    MULTIPOLYGON (((108.75006 13.99063, 108.75006 ...
# 5    MULTIPOLYGON (((108.96382 14.66746, 108.96287 ...
# 6    MULTIPOLYGON (((104.98550 9.65650, 104.99157 9...
# ..                                                 ...
# 703  POLYGON ((106.01446 21.24531, 106.01462 21.245...
# 704  MULTIPOLYGON (((105.54923 21.94792, 105.54914 ...
# 705  MULTIPOLYGON (((105.53794 19.03411, 105.53776 ...
# ...

# %%
# Save the shapefile
merge6_gdf.to_file(r'Vietnam/01_output_stage1/01_vn_available_land.shp')

# %% [markdown]
# ### b. Calculate the total area

# %%
# Original CRS: EPSG:4326 (Unit: longtitude, latitiude)
# Reprojection to crs
map_merge_m_gdf = merge6_gdf.to_crs(crs_m)
# Areas in square kilometers
map_merge_km_df = map_merge_m_gdf.area/ 10**6

# Total areas in square kilometers
print('Total area of', name, ':', map_merge_km_df.sum(axis = 0, skipna = True),'km^2')
# Out:
# Total area of Vietnam : 98024.10436808597 km^2

# %% [markdown]
# ### c. Plot the maps and save the graphs

# %%
# Plot the data with a modified spatial extent
fig, ax = plt.subplots(figsize=(10, 20))

# Use VN_landuse boundary to define all sizes of the maps
ax.set_xlim(101, 110)
ax.set_ylim(8, 24)

# add basemap to the plot (default color)
merge6_gdf.plot(ax=ax, categorical=True, legend=True)

# Set titles
ax.set_title('Vietnam Available Land for renewables Potentials\n(Total Area :{0:.{1}f}km\u00b2)'.format(map_merge_km_df.sum(axis = 0, skipna = True), 2), fontsize=20)
ax.set_axis_off()

# Save the graph into tiff file
plt.savefig(r'Vietnam/01_output_stage1/01_vn_available_land.tif', dpi=400)
plt.show()

# %% [markdown]
# ### d. Save the CSV files

# %%
# Save csv file
# remove column 'geometry' and add column 'area'
map_merge_save_gdf = map_merge_m_gdf.drop(columns=['geometry'])
map_merge_save_gdf['area_km2'] = map_merge_km_df

map_merge_save_gdf.to_csv(r'Vietnam/01_output_stage1/01_vn_avail_land.csv', index = True)
